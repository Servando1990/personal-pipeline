# %% [markdown]
# ## Extensive EDA & Previous Iterations

# %%
import os

# %%
image_path = os.path.abspath('./images')

# %%
from IPython import display
display.Image(image_path + "/creaated_year_is_active.png")

# %% [markdown]
# Observations:
#
# - Tiene sentido que la mayoría de los usuarios no activos se encuentren dentro de una corrupción en los datos como lo es a creación de usuarios despues del presente año

# %%
display.Image(image_path + '/is_active_purchased_atyear.png')

# %% [markdown]
# Sin embargo cuando unimos el dataset podemos ver que efectivamente hay usuarios no activos que estan haciendo transacciones. Aquí falta más contexto de negocio para saber que es lo que realmente significa ser usuario no activo o activo.

# %%
display.Image(image_path + '/value_product_years.png')

# %% [markdown]
# Si queremos desglosar y analizar si todos los productos tienen el mismo comportamiento. Este gráfico nos muestra que para el producto con 4 categorías hay una tendencia uniforme en lo que habíamos visto con la bajada de compras durnate los años

# %%
display.Image(image_path + '/purchased_at_quarter_product.png')

# %% [markdown]
# Si vemos el comportamiento de los productos por Q, hay una clara proyección más a la compra de los productos 2 y 3.
# Q2 tiene una mayor densidad. Aqui podemos analizar má a fondo si tiene que ver con festividades.
# Q4 tiene como producto estrella el 2. Se puede esperar que Q4 tenga mñas densidad ya que aqui hay más poder adquisitivo

# %% [markdown]
# ## Previas iteraciones de modelado

# %%
display.Image(image_path + '/1_it_clusters.png')

# %% [markdown]
# La primera iteración del analisis del clusters, nos dio pistas para crear variables más agregadas en torno a la facturación así como la creación de variables descriptivas por cada canal o variable categoríca

# %%
display.Image(image_path + '/2_it_clusters.png')

# %% [markdown]
# En esta iteración hicimos un perfilado con técnicas de codificación de one-hot-encoding para poder entender una descripción más categórica del perfilado.

# %%
display.Image(image_path + '/3_it_clusters.png')

# %% [markdown]
# Por último en esta tercera iteración entendimos que teníamos que hacer variables descriptivas pero enfocadas en la facturación. Ya que en esta iteración vemos que las variables más explicativas son las agregadas de facturación por Q.
#
# Aqui desarrollamos la estrategia de hacer el analisis con los bin ages post modelado y quedarnos con clusters que representen más la facturación en torno un canal, utm, región, usuario o tiempo de compra.

# %%
display.Image(image_path + '/confusion_matrix.png')

# %% [markdown]
# Hicimos un naive approach de una aproximación para un problema de casificación en donde queriamos resolver el problema de negocio "Propensión a la compra por cartera de productos"
#
# En esta primera iteración y como ya habiamos comprado, la variable target estaba muy desbalanceada. Esto nos iba a representar tiempo y esfuerzo para tunear el algoritmo y emplear técnicas de desbalanceo que quizas que divergan de la naturaleza de los datos, como el uso d variables sintéticas o técnicas de over-sampling

# %%
display.Image(image_path + '/inertia.png')

# %% [markdown]
# El método del codo por la distorsión de los clusters no nos aporto mucha información sobre que número de clusters elegir. Aunque claramente en esta imagén hay mucho trabajo por hacer ya que esto nos dice que no hay mucha inertia o distancia entre los clusters
